# %% [markdown]
# ## MECE Framework

# %% [markdown]
# __Problem Statement__:<br> What are all the factors that could influence residential home prices across the United States over the next decade?

# %% [markdown]
# __MECE__:<br> Mutually exclusive and collectively exhaustive framework helps in problem solving and decision making based on the hypothesis and helps to understand and analyse the problem.(based on the classification)<br>
#
# __Mutually Exclusive__:<br> It aims at reducing complexity by avoiding overlaps. You need to make sure that the possible solutions or groups are not accidentally considered twice. Proving exclusiveness forces you to carefully look at each option, consequently leading you to a much deeper understanding of the issue.
#
# __Collectively Exhaustive__:</br>It aims at ensuring a comprehensive collection without leaving alternatives. Exhaustive means that all possible options have been considered. The trick is to divide a problem into categories with a finite number of general groups.

# %% [markdown]
# ### Factors that affect US residential prices

# %% [markdown]
# ![Screenshot%202022-11-11%20101526.png](attachment:Screenshot%202022-11-11%20101526.png)

# %% [markdown]
# __Demand and Supply__

# %% [markdown]
# These factors affect the buying and selling ratio of residential properties the most. Lets study each factor one by one.

# %% [markdown]
# __Demand__

# %% [markdown]
# __Geographic Specifications__
# 1. Residential price is affected by its location, surroundings and facilities available nearby like market,airport,metro,university,transport etc.
# 2. The more the daily needs, the more the facilities required and more the rent

# %% [markdown]
# __Rental prices and Infaltion rate__
# 1. If the rental prices itself are high when inflation hits then there will be no buyers
# 2. When the inflation is high rental price decreases

# %% [markdown]
# __Economic and Market Conditions__
# 1. If the GDP and stock market crashes resulting in heavy losses of liquid assets decreases property prices
# 2. If economic conditions are good, naturally people can afford the  price above margin

# %% [markdown]
# __Natural Calamities and Outbreak__
# 1. Some uncontrollable factors like floods, pandemic and other large scale destructions result in decrease in rate of buying the properties and so price decreases.

# %% [markdown]
# __Employement, age, Hobbies and Standard of living__
# 1. If the employment rate is higher and if people are earning enough to afford the properties; price goes high
# 2. Age factor has greater influence as people from the age group of 30-50 tends to invest a lot in Residential properties
# 3. People with hobbies of collection and great standard of living greately affect the price and invest a lot in properties
# 4. Entrepreneurs affect the prices with the margin of profit they earn and investments

# %% [markdown]
# Source:__Google__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Supply__

# %% [markdown]
# __Resources to build__
# 1. If the suppply of resources is available and at good price there will be more rental properties available and price will be minimal if the resources to build are rare then the price hits high.

# %% [markdown]
# __Land Availability__
# 1. If the land is available at a proper market place and surrounded by daily facility needs the price wont jumb.
# 2. If the price of land is higher than rental property price will also hit high

# %% [markdown]
# __Govt laws and permissions__
# 1. Some land which has high value may not get permissions from the govt this afects the price
# 2. Some land which has already been rented out may get under govt norms may cause outbreak
# 3. Residential properties built under govt norms has high value

# %% [markdown]
# __Time, weather and cost__
# 1. Residential price is highly effected by the time taken to get the construction complete.
# 2. The weather conditons during the course of construction
# 3. overall cost of construction and resources used during construction

# %% [markdown]
# Source:__Google__

# %% [markdown]
# ![Screenshot%202022-11-11%20120341.png](attachment:Screenshot%202022-11-11%20120341.png)

# %% [markdown]
# __From above we can infer that Over the course of time the price has always increased and it will be increasing over the next decade.__

# %% [markdown]
# __Labor__
# 1. If the labor is good enough to get the work done with ease and labor to provide required services after selling out the properties increases in high demand

# %% [markdown]
# ## Conclusion:
# These are the factors that mostly influence the Residential property price.
